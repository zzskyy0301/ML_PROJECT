# %% [markdown]
# <a href="https://colab.research.google.com/github/zzskyy0301/ML_PROJECT/blob/main/0215.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/zzskyy0301/ML_PROJECT.git
# Out:
# Cloning into 'ML_PROJECT'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 110 (delta 23), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (110/110), 38.14 MiB | 11.44 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# %cd ML_PROJECT/
# Out:
# /content/ML_PROJECT

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2017 NVIDIA Corporation
# Built on Fri_Sep__1_21:08:03_CDT_2017
# Cuda compilation tools, release 9.0, V9.0.176

# %%
pip install -r requirements.txt

# %%
# !pip uninstall -y tensorflow
# !pip install --force-reinstall tensorflow-gpu==1.10
# Out:
# Uninstalling tensorflow-2.4.1:
#   Successfully uninstalled tensorflow-2.4.1
# ...
#   Using cached https://files.pythonhosted.org/packages/64/ca/830b7cedb073ae264d215d51bd18d7cff7a2a47e39d79f6fa23edae17bb2/tensorflow_gpu-1.10.0-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/b6/48/583c032b79ae5b3daa02225a675aeb673e58d2cb698e78510feceb11958c/gast-0.4.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/65/63/39d04c74222770ed1589c0eaba06c05891801219272420b40311cd60c880/wheel-0.36.2-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/bc/58/0aa6fb779dc69cfc811df3398fcbeaeefbf18561b6e36b185df0782781cc/absl_py-0.11.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/68/1e/116ad560de97694e2d0c1843a7a0075cc9f49e922454d32f49a80eb6f1f2/numpy-1.14.5-cp36-cp36m-manylinux1_x86_64.whl
# ...

# %%
# !python dataset_tool_tf.py --input-dir datasets/BSD300/images/train --out=datasets/bsd300.tfrecords
# Out:
# Loading image list from datasets/BSD300/images/train
# 0 datasets/BSD300/images/train/img0000558.jpg
# 1 datasets/BSD300/images/train/img0000231.jpg
# 2 datasets/BSD300/images/train/img0000562.jpg
# 3 datasets/BSD300/images/train/img0000219.jpg
# 4 datasets/BSD300/images/train/img0000467.jpg
# 5 datasets/BSD300/images/train/img0000012.jpg
# 6 datasets/BSD300/images/train/img0000233.jpg
# 7 datasets/BSD300/images/train/img0000641.jpg
# 8 datasets/BSD300/images/train/img0000655.jpg
# 9 datasets/BSD300/images/train/img0000145.jpg
# 10 datasets/BSD300/images/train/img0000637.jpg
# 11 datasets/BSD300/images/train/img0000666.jpg
# 12 datasets/BSD300/images/train/img0000079.jpg
# 13 datasets/BSD300/images/train/img0000204.jpg
# 14 datasets/BSD300/images/train/img0000072.jpg
# 15 datasets/BSD300/images/train/img0000119.jpg
# 16 datasets/BSD300/images/train/img0000614.jpg
# 17 datasets/BSD300/images/train/img0000411.jpg
# 18 datasets/BSD300/images/train/img0000100.jpg
# ...

# %%
# !cd /root/anaconda3
# !cd bin
# !ls
# !wget https://developer.nvidia.com/compute/cuda/9.0/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# !dpkg -i cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# !apt-key add /var/cuda-repo-9-0-local/7fa2af80.pub
# !apt-get update
# !apt-get install cuda=9.0.176-1
# !nvcc -V
# Out:
# /bin/bash: line 0: cd: bin: No such file or directory
# config_mri.py
# config.py
# cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# cuda-repo-ubuntu1704-9-0-176-local-patch-4_1.0-1_amd64-deb
# cuda-repo-ubuntu1704-9-0-local_9.0.176-1_amd64-deb
# dataset.py
# datasets
# dataset_tool_mri.py
# dataset_tool_tf.py
# dnnlib
# download_kodak.py
# LICENSE.txt
# network.py
# noise2noise-master.zip
# README.md
# requirements.txt
# results
# steps.html
# train_mri.py
# train.py
# util.py
# validation.py
# --2021-02-16 03:31:03--  https://developer.nvidia.com/compute/cuda/9.0/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 152.199.16.29
# Connecting to developer.nvidia.com (developer.nvidia.com)|152.199.16.29|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# ...

# %%
#train the network
# !python3 config.py --desc='-test' train --train-tfrecords=datasets/bsd300.tfrecords --long-train=true --noise=gaussian
# Out:
# {'iteration_count': 500, 'eval_interval': 5, 'minibatch_size': 4, 'run_func_name': 'train.train', 'learning_rate': 0.0003, 'ramp_down_perc': 0.5, 'noise': {'func_name': 'train.AugmentGaussian', 'train_stddev_rng_range': (0.0, 50.0), 'validation_stddev': 25.0}, 'noise2noise': True, 'train_tfrecords': 'datasets/bsd300.tfrecords', 'validation_config': {'dataset_dir': 'datasets/kodak'}}
# Creating the run dir: results/00006-autoencoder-test-n2n
# Copying files to the run dir
# dnnlib: Running train.train() on localhost...
# 2021-02-16 04:28:28.427507: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-02-16 04:28:28.528564: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !python3 config.py validate --dataset-dir=datasets/kodak --network-snapshot=results/00006-autoencoder-1gpu-L-n2n/network_final.pickle
# Out:
# Creating the run dir: results/00007-autoencoder
# Copying files to the run dir
# dnnlib: Running validation.validate() on localhost...
# 2021-02-16 04:33:27.088100: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-02-16 04:33:27.184491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-16 04:33:27.185158: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1405] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:04.0
# totalMemory: 15.78GiB freeMemory: 15.07GiB
# 2021-02-16 04:33:27.185191: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1484] Adding visible gpu devices: 0
# ...
